# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5]
y = [12, 13, 14, 15, 16]

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(title='Introduction to Matplotlib')
plt.show()

# %%
# fig.savefig(fname='./Share-Plots/save.png')
